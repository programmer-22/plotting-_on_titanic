# %% [markdown]
# Data Visualization in python

# %% [markdown]
# # Plotting in python
# # By: Huma Munawar

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import dataset
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# check ko sa parameter kya batha rha hai
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# check null values
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.survived.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
# another way
sns.countplot(x="survived", hue="sex", data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
import seaborn as sns

# %%
# scatter plot
plt.scatter(data=kashti, x="age", y="fare", cmap="pclass")# c= Numeric columns for color map
# syntaxc=df["pclass"]
# cmap="pclass"
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3824\2492123062.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(data=kashti, x="age", y="fare", cmap="pclass")# c= Numeric columns for color map

# %%
sns.scatterplot(data=kashti, x="age", y="fare", hue="pclass") # Category coloring (seaborn)
#syntax hue="pclass"
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(data=kashti, x="sex", y="fare", hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# most important plot
sns.pairplot(kashti)# har variable ko other variable kay against draw kya ja tha hai

# %%
kashti.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
# hist plot
kashti.hist(bins=10,figsize=(9,7),grid=False)#histogramplot
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.boxplot(data=kashti, x="sex", y="fare", hue="embark_town")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %% [markdown]
# # Assignment
# How to change the x and y axis titles?

# %%
# subplot
g = sns.FacetGrid(kashti, hue="survived", col="pclass", margin_titles=True,
                  palette={1:"seagreen", 0:"gray"})

# %%
g = sns.FacetGrid(kashti, hue="survived", col="pclass", margin_titles=True,
                  palette={1:"seagreen", 0:"gray"})
g = g.map(plt.scatter, "fare", "age", edgecolor="w").add_legend();

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
g = sns.FacetGrid(kashti, hue="survived", col="embark_town", margin_titles=True,
                  palette={1:"seagreen", 0:"gray"})
g = g.map(plt.scatter, "fare", "age", edgecolor="w").add_legend();

# %%
#strip plot is the cobmination of bar and scatter plot
sns.stripplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# corr relation
corr = kashti.corr
corr
# Out:
# <bound method DataFrame.corr of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import seaborn as sns

# %%
#Heat map
corr = kashti.corr(numeric_only=True)
plt.figure(figsize=(10,10))
sns.heatmap(corr)
plt.title("heatmap of titanic")
# Out:
# Text(0.5, 1.0, 'heatmap of titanic')

# %%
sns.violinplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>
